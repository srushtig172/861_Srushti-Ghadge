# %% [markdown]
# <a href="https://colab.research.google.com/github/srushtig172/861_Srushti-Ghadge/blob/main/202201090125_Lab_Assignment4_NLP_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Colab Lab Assignment -NLP
#
# **Course Name:** [Deep Learning]
#
# **Lab Title:** NLP Techniques for Text Classification
#
# **Student Name:**[Srushti Ghadge]
#
# **Student ID:**[202210190125]
#
# **Date of Submission:** [22/04/2025]
#
# **Group Members**: [Samruddhi Bhujbal, Snehal Bankar]
#
#
# **Objective**
# The objective of this assignment is to implement NLP preprocessing techniques and build a text classification model using machine learning techniques.

# %% [markdown]
# **NLP- Example ffor Single Sentence**

# %% [markdown]
# **1. Tokenization**
#
# Tokenization is the process of breaking text into smaller units, such as sentences or words.
#
# **Sentence Tokenization**
#
# This splits a paragraph into individual sentences.
#
# Example:
# Input: "John works at Google. He lives in New York and loves programming in Python."
#
# Output: ["John works at Google.", "He lives in New York and loves programming in Python."]
#
# **Word Tokenization**
#
# This splits sentences into individual words.
#
# Example:
#
# Input: "John works at Google."
# Output: ["John", "works", "at", "Google", "."]
# 🔹 Why is it important?
# Helps in text processing by breaking down data into meaningful elements.
#
# **2. Stopword Removal**
#
# Stopwords are common words that do not add much meaning to a sentence, such as "is," "the," "at," "in," "and," etc.
#
# Removing stopwords helps in reducing noise and improving the efficiency of NLP models.
#
# Example:
# Input: "He is working at Google in New York."
# Without Stopwords: ["He", "working", "Google", "New York"]
#
# 🔹 Why is it important?
# Reduces data size and processing time.
# Focuses on meaningful words.
#
# **3. Lemmatization**
#
# Converts words to their root or dictionary form (lemma).
#
# Unlike stemming, which simply chops off word endings (e.g., "running" → "runn"), lemmatization ensures that the word retains its meaning.
#
# Example:
# Word	Lemmatized Form
# Running	Run
# Better	Good
# Studies	Study
# 🔹 Why is it important?
#
# Standardizes words to improve NLP model accuracy.
# Avoids redundancy in word forms.
#
# **4. Part-of-Speech (POS) Tagging**
#
# Assigns grammatical categories (like nouns, verbs, adjectives) to words.
# Helps in understanding sentence structure.
# Example:
# Input: "John works at Google."
# Output:
# [("John", "NNP"), ("works", "VBZ"), ("at", "IN"), ("Google", "NNP")]
#
# NNP (Proper Noun) → "John", "Google"
# VBZ (Verb, 3rd person singular present) → "works"
# IN (Preposition) → "at"
# 🔹 Why is it important?
#
# Useful in text analysis, information retrieval, and machine translation.
# Helps with Named Entity Recognition (NER).
#
# **5. Named Entity Recognition (NER)**
#
# Identifies and categorizes names, locations, organizations, dates, and more.
#
# Example:
# Input: "John works at Google in New York."
# Output:
# [("John", PERSON), ("Google", ORG), ("New York", GPE)]
#
# PERSON → "John"
#
# ORG (Organization) → "Google"
#
# GPE (Geopolitical Entity, like a city or country) → "New York"
#
# 🔹 Why is it important?
# Used in chatbots, search engines, and data extraction.
# Helps machines understand real-world entities.

# %% [markdown]
# **1. Corpora & Datasets**
# NLTK includes several built-in corpora that can be accessed using nltk.corpus.
#
# **brown –** The Brown Corpus, a balanced dataset of English texts from different categories.
#
# **gutenberg –** A collection of literary texts from Project Gutenberg.
#
# **reuters –** News documents from the Reuters corpus.
#
# **stopwords**– A list of common stopwords for various languages.
#
# **wordnet –**A lexical database for English that provides synonyms, antonyms, and definitions.
#
# **words –** A list of words from a dictionary
#
# **names –** A list of male and female names.

# %% [markdown]
# **2. Tokenizers**
# NLTK provides tools for breaking text into words and sentences.
#
#
# **punkt –** A pre-trained tokenizer model for sentence splitting.
#
# **word_tokenize –** Tokenizes a sentence into words.
#
# **sent_tokenize –** Splits a paragraph into sentences.

# %% [markdown]
# **3. Stemmers & Lemmatizers**
# Used for reducing words to their base forms.
#
# **PorterStemmer –** Uses stemming to reduce words to their root form.
#
# **LancasterStemmer –** A more aggressive stemming algorithm.
#
# **WordNetLemmatizer**– Uses WordNet to find the base (lemma) of words.

# %% [markdown]
# **averaged_perceptron_tagger in NLTK**
#
# The averaged_perceptron_tagger is a pre-trained Part-of-Speech (POS) tagger in NLTK that uses the Averaged Perceptron algorithm to assign grammatical labels (POS tags) to words in a sentence.

# %% [markdown]
# **maxent_ne_chunker - Named Entity Chunker**
#
# Uses the Maximum Entropy model to identify named entities in a text.
# It is trained on the CoNLL 2000 corpus, a well-known dataset for chunking.
# Identifies entities like PERSON, ORGANIZATION, LOCATION, GPE (Geo-Political Entity), DATE, TIME, MONEY, etc.

# %% [markdown]
# **maxent_ne_chunker_tab is a tab-separated version of the maxent_ne_chunker model.**
# It is internally used by NLTK for:
#
# Storing pre-trained Named Entity Recognition (NER) data.
# Retrieving entity-related information in a structured format.
#
# ** Key Points:**
# It is not directly used by users.
# It functions as a supporting resource for maxent_ne_chunker.
# It helps in efficient chunking by storing entity rules in a tab-separated format.

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, ne_chunk

# Download necessary NLTK resources
nltk.download('punkt')  # Tokenization
nltk.download('stopwords')  # Stopwords for filtering
nltk.download('wordnet')  # Lemmatization
nltk.download('averaged_perceptron_tagger')  # POS tagging
nltk.download('maxent_ne_chunker')  # Named Entity Recognition (NER)
nltk.download('words')  # Dictionary for NER
nltk.download('punkt_tab') # Download the punkt_tab resource
nltk.download('averaged_perceptron_tagger_eng') #download the english version of the tagger
nltk.download('maxent_ne_chunker_tab') # Download the correct tab resource for ne_chunker

# Sample text for NLP processing
text = "John works at Google. He lives in New York and loves programming in Python."

# Step 1: Sentence Tokenization - Splitting text into sentences
sentences = sent_tokenize(text)
print("Sentence Tokenization:", sentences)

# Step 2: Word Tokenization - Splitting sentences into words
words = word_tokenize(text)
print("\nWord Tokenization:", words)

# Step 3: Removing Stopwords - Filtering out common words like 'the', 'is', etc.
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words]
print("\nAfter Stopword Removal:", filtered_words)

# Step 4: Lemmatization - Reducing words to their base form
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
print("\nAfter Lemmatization:", lemmatized_words)

# Step 5: Part-of-Speech Tagging - Assigning grammatical categories to words
pos_tags = pos_tag(words)
print("\nPOS Tagging:", pos_tags)

# Step 6: Named Entity Recognition (NER) - Identifying names, places, and organizations
ner_tree = ne_chunk(pos_tags)
print("\nNamed Entity Recognition:")
ner_tree.pretty_print()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# ...

# %%
# Importing necessary libraries
import pandas as pd

# Load the data (replace the URL with your file path or use upload functionality)
url = '/content/emotion_sentimen_dataset.csv'  # Use your dataset URL
data = pd.read_csv(url)

# Display the first few rows of the data
data.head()
# Out:
#    Unnamed: 0                                               text  Emotion
# 0           0  i seriously hate one subject to death but now ...     hate
# 1           1                 im so full of life i feel appalled  neutral
# 2           2  i sit here to write i start to dig out my feel...  neutral
# 3           3  ive been really angry with r and i feel like a...    anger
# 4           4  i feel suspicious if there is no one outside l...  neutral

# %%
# Install NLTK
# !pip install nltk

# Import NLTK and download required resources
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize

# Ensure nltk resources are downloaded
nltk.download('punkt')

# Convert non-string values to empty strings
data['tokenized_text'] = data['text'].astype(str).apply(word_tokenize)

# Display the tokenized reviews
data[['text', 'tokenized_text']].head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                 text  \
# 0  i seriously hate one subject to death but now ...
# 1                 im so full of life i feel appalled
# 2  i sit here to write i start to dig out my feel...
# 3  ive been really angry with r and i feel like a...
# 4  i feel suspicious if there is no one outside l...
#
#                                       tokenized_text
# 0  [i, seriously, hate, one, subject, to, death, ...
# 1        [im, so, full, of, life, i, feel, appalled]
# 2  [i, sit, here, to, write, i, start, to, dig, o...
# 3  [ive, been, really, angry, with, r, and, i, fe...
# 4  [i, feel, suspicious, if, there, is, no, one, ...

# %%
data['text'] = data['text'].fillna('')  # Replace NaN with empty string
data['tokenized_text'] = data['text'].apply(word_tokenize)

# %%
from nltk.tokenize import word_tokenize

# Tokenize the reviews
data['tokenized_text'] = data['text'].apply(word_tokenize)

# Display the tokenized reviews
data[['text', 'tokenized_text']].head()
# Out:
#                                                 text  \
# 0  i seriously hate one subject to death but now ...
# 1                 im so full of life i feel appalled
# 2  i sit here to write i start to dig out my feel...
# 3  ive been really angry with r and i feel like a...
# 4  i feel suspicious if there is no one outside l...
#
#                                       tokenized_text
# 0  [i, seriously, hate, one, subject, to, death, ...
# 1        [im, so, full, of, life, i, feel, appalled]
# 2  [i, sit, here, to, write, i, start, to, dig, o...
# 3  [ive, been, really, angry, with, r, and, i, fe...
# 4  [i, feel, suspicious, if, there, is, no, one, ...

# %%
# Convert tokens to lowercase
data['lowercase_text'] = data['tokenized_text'].apply(lambda x: [word.lower() for word in x])

# Display the lowercase tokens
data[['text', 'lowercase_text']].head()
# Out:
#                                                 text  \
# 0  i seriously hate one subject to death but now ...
# 1                 im so full of life i feel appalled
# 2  i sit here to write i start to dig out my feel...
# 3  ive been really angry with r and i feel like a...
# 4  i feel suspicious if there is no one outside l...
#
#                                       lowercase_text
# 0  [i, seriously, hate, one, subject, to, death, ...
# 1        [im, so, full, of, life, i, feel, appalled]
# 2  [i, sit, here, to, write, i, start, to, dig, o...
# 3  [ive, been, really, angry, with, r, and, i, fe...
# 4  [i, feel, suspicious, if, there, is, no, one, ...

# %%
from nltk.corpus import stopwords

# Get English stopwords
stop_words = set(stopwords.words('english'))

# Remove stop words from the tokens
data['cleaned_text'] = data['lowercase_text'].apply(lambda x: [word for word in x if word not in stop_words])

# Display the cleaned tokens (without stop words)
data[['text', 'cleaned_text']].head()
# Out:
#                                                 text  \
# 0  i seriously hate one subject to death but now ...
# 1                 im so full of life i feel appalled
# 2  i sit here to write i start to dig out my feel...
# 3  ive been really angry with r and i feel like a...
# 4  i feel suspicious if there is no one outside l...
#
#                                         cleaned_text
# 0  [seriously, hate, one, subject, death, feel, r...
# 1                   [im, full, life, feel, appalled]
# 2  [sit, write, start, dig, feelings, think, afra...
# 3  [ive, really, angry, r, feel, like, idiot, tru...
# 4  [feel, suspicious, one, outside, like, rapture...

# %%
import string

# Get English stopwords
stop_words = set(stopwords.words('english'))

# Get the set of all punctuation marks
punctuation = set(string.punctuation)

# Remove stop words and punctuation from the tokens
data['cleaned_text'] = data['lowercase_text'].apply(lambda x: [word for word in x if word not in stop_words and word not in punctuation])

# Display the cleaned tokens (without stop words and punctuation)
data[['text', 'cleaned_text']].head()
# Out:
#                                                 text  \
# 0  i seriously hate one subject to death but now ...
# 1                 im so full of life i feel appalled
# 2  i sit here to write i start to dig out my feel...
# 3  ive been really angry with r and i feel like a...
# 4  i feel suspicious if there is no one outside l...
#
#                                         cleaned_text
# 0  [seriously, hate, one, subject, death, feel, r...
# 1                   [im, full, life, feel, appalled]
# 2  [sit, write, start, dig, feelings, think, afra...
# 3  [ive, really, angry, r, feel, like, idiot, tru...
# 4  [feel, suspicious, one, outside, like, rapture...

# %%
import re

# Function to remove special characters from tokens
def remove_special_characters(text):
    # Use regex to keep only alphanumeric characters (letters and numbers)
    cleaned_text = [re.sub(r'\W+', '', word) for word in text if re.sub(r'\W+', '', word) != '']
    return cleaned_text

# Remove stop words, punctuation, and special characters from tokens
data['cleaned_text'] = data['lowercase_text'].apply(lambda x: [word for word in x if word not in stop_words and word not in punctuation])

# Apply the function to remove special characters
data['cleaned_text'] = data['cleaned_text'].apply(remove_special_characters)

# Drop duplicate reviews (if any)
data.drop_duplicates(subset='text', keep='first', inplace=True)

# Display the cleaned tokens (without special characters and duplicates)
data[['text', 'cleaned_text']].head()
# Out:
#                                                 text  \
# 0  i seriously hate one subject to death but now ...
# 1                 im so full of life i feel appalled
# 2  i sit here to write i start to dig out my feel...
# 3  ive been really angry with r and i feel like a...
# 4  i feel suspicious if there is no one outside l...
#
#                                         cleaned_text
# 0  [seriously, hate, one, subject, death, feel, r...
# 1                   [im, full, life, feel, appalled]
# 2  [sit, write, start, dig, feelings, think, afra...
# 3  [ive, really, angry, r, feel, like, idiot, tru...
# 4  [feel, suspicious, one, outside, like, rapture...

# %%
# Do NOT run this code - it is for reference only

# from nltk.stem import PorterStemmer

# # Initialize the stemmer
# stemmer = PorterStemmer()

# # Apply stemming to the tokens
# data['stemmed_reviews'] = data['cleaned_reviews'].apply(lambda x: [stemmer.stem(word) for word in x])

# # Display the stemmed tokens
# data[['reviews.text', 'stemmed_reviews']].head()

# %%
from nltk.stem import WordNetLemmatizer

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# Apply lemmatization to the tokens
data['lemmatized_text'] = data['cleaned_text'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])

# Display the lemmatized tokens
data[['text', 'lemmatized_text']].head()
# Out:
#                                                 text  \
# 0  i seriously hate one subject to death but now ...
# 1                 im so full of life i feel appalled
# 2  i sit here to write i start to dig out my feel...
# 3  ive been really angry with r and i feel like a...
# 4  i feel suspicious if there is no one outside l...
#
#                                      lemmatized_text
# 0  [seriously, hate, one, subject, death, feel, r...
# 1                   [im, full, life, feel, appalled]
# 2  [sit, write, start, dig, feeling, think, afrai...
# 3  [ive, really, angry, r, feel, like, idiot, tru...
# 4  [feel, suspicious, one, outside, like, rapture...

# %%
# Download VADER for sentiment analysis
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Initialize the VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Apply sentiment analysis to lemmatized reviews
data['sentiment_scores'] = data['tokenized_text'].apply(lambda review: sid.polarity_scores(' '.join(review)))

# Extract compound sentiment score (overall sentiment)
data['compound_score'] = data['sentiment_scores'].apply(lambda score_dict: score_dict['compound'])

# Categorize reviews based on compound score
data['sentiment'] = data['compound_score'].apply(lambda x: 'positive' if x >= 0.05 else ('negative' if x <= -0.05 else 'neutral'))

# Display reviews with their sentiment
data[['text', 'tokenized_text', 'compound_score', 'sentiment']].head()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
#                                                 text  \
# 0  i seriously hate one subject to death but now ...
# 1                 im so full of life i feel appalled
# 2  i sit here to write i start to dig out my feel...
# 3  ive been really angry with r and i feel like a...
# 4  i feel suspicious if there is no one outside l...
#
#                                       tokenized_text  compound_score sentiment
# 0  [i, seriously, hate, one, subject, to, death, ...         -0.8519  negative
# 1        [im, so, full, of, life, i, feel, appalled]         -0.4588  negative
# 2  [i, sit, here, to, write, i, start, to, dig, o...          0.3818  positive
# 3  [ive, been, really, angry, with, r, and, i, fe...         -0.4005  negative
# 4  [i, feel, suspicious, if, there, is, no, one, ...         -0.1531  negative

# %%
# Install WordCloud
# !pip install wordcloud

# Import required libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Combine all lemmatized reviews into a single string
all_lemmatized_reviews = ' '.join([' '.join(review) for review in data['lemmatized_text']])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_lemmatized_reviews)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off the axis
plt.show()

# %%
# Calculate word counts for each review (lemmatized)
data['word_count'] = data['lemmatized_text'].apply(len)

# Display summary statistics of word counts
data['word_count'].describe()
# Out:
# count    18480.000000
# mean         9.394535
# std          5.243518
# min          0.000000
# 25%          5.000000
# 50%          8.000000
# 75%         12.000000
# max         34.000000
# Name: word_count, dtype: float64

# %%
# Plotting the distribution of word counts
plt.figure(figsize=(10, 6))
plt.hist(data['word_count'], bins=20, color='blue', edgecolor='black')
plt.title('Distribution of Word Counts in Reviews')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.show()

# %%
# Plotting the distribution of review ratings
plt.figure(figsize=(8, 5))
data['text'].value_counts().sort_index().plot(kind='bar', color='green', edgecolor='black')
plt.title('Distribution of Review Ratings')
plt.xlabel('Ratings')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=0)
plt.show()

# %%
# Plotting the distribution of sentiment scores
plt.figure(figsize=(10, 6))
plt.hist(data['compound_score'], bins=30, color='purple', edgecolor='black')
plt.title('Distribution of Compound Sentiment Scores')
plt.xlabel('Compound Score')
plt.ylabel('Frequency')
plt.show()

# %%
from collections import Counter

# Count the frequency of each word in all reviews
all_words = [word for review in data['lemmatized_text'] for word in review]
word_freq = Counter(all_words)

# Display the 10 most common words
common_words = word_freq.most_common(10)
print(common_words)

# Plot the most common words
words, counts = zip(*common_words)
plt.figure(figsize=(10, 6))
plt.bar(words, counts, color='orange', edgecolor='black')
plt.title('Top 10 Most Common Words in Lemmatized text')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.show()
# Out:
# [('feel', 13112), ('feeling', 6372), ('like', 3277), ('im', 2767), ('time', 1176), ('really', 1130), ('know', 1056), ('little', 900), ('get', 893), ('thing', 849)]

# %%
# Create a boxplot to visualize sentiment scores by review ratings
plt.figure(figsize=(10, 6))
data.boxplot(column='compound_score', by='Emotion', grid=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.title('Sentiment Score Distribution by Emotion')
plt.suptitle('')  # Suppress the automatic title
plt.xlabel('Emotion')
plt.ylabel('Compound Sentiment Score')
plt.show()

# %% [markdown]
# D

# %% [markdown]
# # **Document Silimlarity **

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Sample documents
documents = [
    "The flower is brightly blooming.",
    "The sun is shining luminously.",
    "The river was very deep.",
    "The sun raises in east",
]

# Step 1: Convert the documents to TF-IDF vectors
vectorizer = TfidfVectorizer()

# Transform the documents into TF-IDF matrix
tfidf_matrix = vectorizer.fit_transform(documents)
print(tfidf_matrix)
# Step 2: Compute the Cosine Similarity between the documents
cosine_sim_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Step 3: Display the similarity matrix
print("Cosine Similarity Matrix:")
print(cosine_sim_matrix)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 20 stored elements and shape (4, 15)>
#   Coords	Values
#   (0, 12)	0.2644512224141842
#   (0, 4)	0.506765426545092
#   (0, 6)	0.3995396830595886
#   (0, 1)	0.506765426545092
#   (0, 0)	0.506765426545092
#   (1, 12)	0.27832025279307177
#   (1, 6)	0.42049336953280086
#   (1, 11)	0.42049336953280086
#   (1, 10)	0.5333425209202354
#   (1, 7)	0.5333425209202354
#   (2, 12)	0.25246826075544676
#   (2, 9)	0.4838025881780501
#   (2, 14)	0.4838025881780501
#   (2, 13)	0.4838025881780501
#   (2, 2)	0.4838025881780501
#   (3, 12)	0.2644512224141842
#   (3, 11)	0.3995396830595886
#   (3, 8)	0.506765426545092
#   (3, 5)	0.506765426545092
#   (3, 3)	0.506765426545092
# Cosine Similarity Matrix:
# [[1.         0.24160592 0.06676554 0.06993445]
#  [0.24160592 1.         0.07026703 0.24160592]
#  [0.06676554 0.07026703 1.         0.06676554]
#  [0.06993445 0.24160592 0.06676554 1.        ]]

# %% [markdown]
# **Declaration**
#
# I,Srushti Ghadge, confirm that the work submitted in this assignment is my own and has been completed following academic integrity guidelines. The code is uploaded on my GitHub repository account, and the repository link is provided below:
#
# GitHub Repository Link: [Insert GitHub Link]
#
# Signature: Srushti Ghadge
